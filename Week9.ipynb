# %% [markdown]
# <a href="https://colab.research.google.com/github/veronichaflasma/PCVK_Genap_2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
from skimage import io
from skimage import transform
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.morphology import (erosion, dilation, closing, opening, area_closing, area_opening)
from skimage.color import rgb2gray

# %%
#number 3
img = cv.imread('/content/drive/MyDrive/Image_PCVK/j.png')

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Initial Image')
plt.subplot(122),plt.imshow(dilation),plt.title('Dilated Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7e035ad10>,
#  <matplotlib.image.AxesImage at 0x7fc7e20cc790>,
#  Text(0.5, 1.0, 'Dilated Result Image'))

# %%
#number 4
img1= cv.imread('/content/drive/MyDrive/Image_PCVK/j.png', 0)

m,n= img1.shape 

plt.imshow(img1, cmap="gray")

k=5
SE= np.ones((k,k), dtype=np.uint8)
constant= (k-1)//2

imgErode= np.zeros((m,n), dtype=np.uint8)

for i in range(constant, m-constant):
  for j in range(constant,n-constant):
    temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
    product= temp*SE
    imgErode[i,j]= np.min(product)
plt.subplot(121), plt.imshow(img1, cmap ="gray"), plt.title('Initial Image')
plt.subplot(122), plt.imshow(imgErode, cmap="gray"), plt.title('Erosion Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7e0262550>,
#  <matplotlib.image.AxesImage at 0x7fc7dfc6b290>,
#  Text(0.5, 1.0, 'Erosion Result Image'))

# %%
#number 5
kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(dilation), plt.title('Erosion Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7dfd30d90>,
#  <matplotlib.image.AxesImage at 0x7fc7dfbfdb10>,
#  Text(0.5, 1.0, 'Erosion Result Image'))

# %%
#number 6
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erosion Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7dfb4c3d0>,
#  <matplotlib.image.AxesImage at 0x7fc7dfacae90>,
#  Text(0.5, 1.0, 'Erosion Result Image'))

# %%
#number 7
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(opening), plt.title('Opening Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7dfa8bd90>,
#  <matplotlib.image.AxesImage at 0x7fc7dfa1dfd0>,
#  Text(0.5, 1.0, 'Opening Result Image'))

# %%
#number 8
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(closing), plt.title('Closing Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7df8d9c90>,
#  <matplotlib.image.AxesImage at 0x7fc7df843550>,
#  Text(0.5, 1.0, 'Closing Result Image'))

# %%
#number 9
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(cross3), plt.title('3x3 Dilation Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7df7fd350>,
#  <matplotlib.image.AxesImage at 0x7fc7df764510>,
#  Text(0.5, 1.0, '3x3 Dilation Result Image'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(cross3), plt.title('5x5 Dilation Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7df7fd190>,
#  <matplotlib.image.AxesImage at 0x7fc7df6adf90>,
#  Text(0.5, 1.0, '5x5 Dilation Result Image'))

# %%
#number 10
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(cross3), plt.title('3x3 Circular Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7dfd7ced0>,
#  <matplotlib.image.AxesImage at 0x7fc7dfb6ce90>,
#  Text(0.5, 1.0, '3x3 Circular Result Image'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(cross3), plt.title('5x5 Circular Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7df354210>,
#  <matplotlib.image.AxesImage at 0x7fc7df2d8f90>,
#  Text(0.5, 1.0, '5x5 Circular Result Image'))

# %%
#number 11
kernel = cv.getStructuringElement(cv.MORPH_RECT, (3, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(cross3), plt.title('3x5 Rectangle Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7df496dd0>,
#  <matplotlib.image.AxesImage at 0x7fc7df385cd0>,
#  Text(0.5, 1.0, '3x5 Rectangle Result Image'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(cross3), plt.title('Rectangle 5x7 Result Image')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7df5089d0>,
#  <matplotlib.image.AxesImage at 0x7fc7df4b0c50>,
#  Text(0.5, 1.0, 'Rectangle 5x7 Result Image'))

# %%
#number 12
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 5))
cross4 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(cross4), plt.title('Line Vertical Result Image 5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc7dfc3e490>,
#  <matplotlib.image.AxesImage at 0x7fc7df56f550>,
#  Text(0.5, 1.0, 'Line Vertical Result Image 5'))
